# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)
plt.scatter(x,y, s=10)
plt.show()

# %%
data = {'axis' : [], 'r2' : [], 'rmse' : []}

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()

print("R2 Score:", end='\t')
print(r2_score(y, y_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_pred)))

data['axis'].append(1)
data['r2'].append(r2_score(y, y_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_pred)))
# Out:
# R2 Score:	0.6386750054827146
# Root mean square error:	15.908242501429998

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(2)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.8537647164420812
# Root mean square error:	10.120437473614711

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(3)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9830071790386679
# Root mean square error:	3.449895507408724

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=4)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(4)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9841082585798676
# Root mean square error:	3.336252753337377

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=5)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(5)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9845143345421614
# Root mean square error:	3.293351887947393

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=6)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(6)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9846246040024639
# Root mean square error:	3.2816053816781694

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=7)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(7)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9849270888257704
# Root mean square error:	3.249165028504877

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=8)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(8)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9851541074904565
# Root mean square error:	3.224603760678202

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=9)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(9)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.99355822094593
# Root mean square error:	2.1241056430814975

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=10)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(10)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9941487971704481
# Root mean square error:	2.024397427560471

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=11)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(11)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9945876873764838
# Root mean square error:	1.946994108406013

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=12)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(12)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9953295697007862
# Root mean square error:	1.8086379857275072

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=13)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(13)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9960228105097249
# Root mean square error:	1.669019234960023

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=14)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(14)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9964621771791349
# Root mean square error:	1.5741323340085587

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=15)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(15)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9970642753009166
# Root mean square error:	1.4339396169230527

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=16)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(16)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9970914742544038
# Root mean square error:	1.4272815652201734

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=17)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(17)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9997131553821708
# Root mean square error:	0.44822549241093146

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=18)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(18)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9997061057349201
# Root mean square error:	0.4536999757249192

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=19)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(19)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9996920555658867
# Root mean square error:	0.4644183591610674

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=20)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(20)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9982308265442509
# Root mean square error:	1.1131620902350652

# %%
import operator

import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=21)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(21)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9984782332316998
# Root mean square error:	1.0323982227139303

# %%
import operator

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

polynomial_features= PolynomialFeatures(degree=22)
x_poly = polynomial_features.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

print("R2 Score:", end='\t')
print(r2_score(y, y_poly_pred))

print("Root mean square error:", end='\t')
print(np.sqrt(mean_squared_error(y, y_poly_pred)))

data['axis'].append(22)
data['r2'].append(r2_score(y, y_poly_pred))
data['rmse'].append(np.sqrt(mean_squared_error(y, y_poly_pred)))

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
x, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()
# Out:
# R2 Score:	0.9968243016811827
# Root mean square error:	1.491395470716354

# %%
pd.DataFrame(data)
# Out:
#     axis        r2       rmse
# 0      1  0.638675  15.908243
# 1      2  0.853765  10.120437
# 2      3  0.983007   3.449896
# 3      4  0.984108   3.336253
# 4      5  0.984514   3.293352
# 5      6  0.984625   3.281605
# 6      7  0.984927   3.249165
# 7      8  0.985154   3.224604
# 8      9  0.993558   2.124106
# 9     10  0.994149   2.024397
# 10    11  0.994588   1.946994
# 11    12  0.995330   1.808638
# 12    13  0.996023   1.669019
# 13    14  0.996462   1.574132
# 14    15  0.997064   1.433940
# 15    16  0.997091   1.427282
# 16    17  0.999713   0.448225
# 17    18  0.999706   0.453700
# 18    19  0.999692   0.464418
# 19    20  0.998231   1.113162
# 20    21  0.998478   1.032398
# 21    22  0.996824   1.491395

# %%
plt.plot(data['axis'], data['r2'], label = 'r2 score')
plt.legend()

# %%
plt.plot(data['axis'], data['rmse'], label = 'root mean square error')
plt.legend()
