# %%
import pandas as pd

# %%
df = pd.read_html('https://docs.google.com/spreadsheets/d/1ifL1poO_Kcfng9pWM3WE9MOQFUV_kv_52U07ttVrZOI/edit#gid=1448380838', header=1)[0]

# %%
df2 = df.drop(['1', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1).dropna().astype({'Roll_No' : int, 'Name' : str, 'Timestamp' : 'datetime64'})

# %%
df2.dtypes
# Out:
# Timestamp          datetime64[ns]
# Name                       object
# Roll_No                     int32
# Assignment_File            object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
df2
# Out:
#              Timestamp                     Name  Roll_No  \
# 1  2019-11-18 20:41:40              Aditya Pade       31
# 2  2019-11-18 21:32:17          Vaidehi Fulzele       16
# 3  2019-11-18 22:26:08           AKSHADA TONAPE       39
# 4  2019-11-19 19:51:01          Chinar Sakrikar       36
# 5  2019-11-19 19:58:13         maithilee gurjar       19
# 6  2019-11-19 20:01:57             Yash ghaisas       42
# 7  2019-11-19 20:04:35               Anuja Apte        3
# 8  2019-11-19 20:05:06         Maithilee Gurjar       19
# 9  2019-11-19 20:44:56             Rahul Pathak       34
# 10 2019-11-19 21:03:11           Bhargavi Joshi       21
# 11 2019-11-19 21:11:12              Bhalchandra       27
# 12 2019-11-19 21:24:34             Aniket Walse       41
# 13 2019-11-19 21:46:09  swati shrikant baviskar        5
# 14 2019-11-19 22:12:25             Aadesh Dalvi       11
# 15 2019-11-19 22:21:59         Gayatri Ambulkar        2
# ...

# %%
from docx import Document
import time

# %%
doc = Document()

# %%
doc.add_heading('Report as of {}'.format(time.ctime()))

# %%
doc.add_paragraph('\nText')

# %%
doc.save('prototype2.docx')
